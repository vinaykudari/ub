# %%
# add parent directory to path: enable import from parent dir
import sys
sys.path.append('../')

from agents.actor_critic import A2C
from networks.a2c.actor import Actor
from networks.a2c.critic import Critic

import gym
import matplotlib.pyplot as plt
import torch

# %%
env = gym.make('LunarLander-v2')

# %%
actor_model = Actor(
    state_dim=env.observation_space.shape[0],
    action_dim=env.action_space.n,
)
critic_model = Critic(state_dim=env.observation_space.shape[0])
a2c = A2C(
    env=env, 
    actor=actor_model,
    critic=critic_model,
    n_actns=env.action_space.n,
    actor_optmz=torch.optim.Adam(actor_model.parameters(), lr=0.001),
    critic_optmz=torch.optim.Adam(critic_model.parameters(), lr=0.001),
    hyprprms={
        'gamma': 0.995,
    },
    log_freq=300,
)

# %%
a2c.run(5000)
# Out:
# Episode: 0, Loss: 0.7891081086154286, Avg. Reward: -188.62478581326118
# Episode: 300, Loss: -0.04905406944545316, Avg. Reward: -373.01847268198514
# Episode: 600, Loss: 0.800606381715377, Avg. Reward: -45.86157111355348
# Episode: 900, Loss: 1.7330897030900152, Avg. Reward: -5.302156183824215
# Episode: 1200, Loss: 1.431568907825492, Avg. Reward: -17.6680867970987
# Episode: 1500, Loss: 0.7012709944793175, Avg. Reward: -101.17404238619287
# Episode: 1800, Loss: 0.038081707466873616, Avg. Reward: -37.521464902326784
# Episode: 2100, Loss: -0.21891629882980046, Avg. Reward: 28.214089474712267
# Episode: 2400, Loss: 0.9254768487802658, Avg. Reward: 41.526315733470746
# Episode: 2700, Loss: 0.6560460558407162, Avg. Reward: 25.15195624690688
# Episode: 3000, Loss: 0.3594192178037231, Avg. Reward: 67.62768171665401
# Episode: 3300, Loss: -0.21177999230498468, Avg. Reward: 56.22208321374947
# Episode: 3600, Loss: -0.19942754582705957, Avg. Reward: 4.105208049563686
# Episode: 3900, Loss: 0.24812707429288927, Avg. Reward: 124.22618870236002
# Episode: 4200, Loss: 0.058464591126247634, Avg. Reward: 165.5090935864394
# Episode: 4500, Loss: 0.11622970447981795, Avg. Reward: 153.13062566407035
# Episode: 4800, Loss: 0.12762526694681503, Avg. Reward: 182.530867500583

# %%
a2c.evaluate()

# %% [markdown]
# ## Training

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 8))

total_rewards = [log['reward'] for _, log in a2c.logs.items()]
mean_rewards = sum(total_rewards)/len(total_rewards)
ax[0].plot(range(5000), total_rewards)
ax[0].text(0.5, 0.7, f'Average reward per episode: {round(mean_rewards, 2)}', transform=ax[0].transAxes, size='large')
ax[0].set_title('Total reward per episode')

cumulative_rewards = [log['avg_reward'] for _, log in a2c.logs.items()]
ax[1].plot(range(5000), cumulative_rewards)
ax[1].set_title('Average reward per episode')
# Out:
# Text(0.5, 1.0, 'Average reward per episode')

# %% [markdown]
# ## Evaluation

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 8))

total_rewards = [log['reward'] for _, log in a2c.eval_logs.items()]
mean_rewards = sum(total_rewards)/len(total_rewards)
ax[0].plot(range(50), total_rewards)
ax[0].text(0.5, 0.7, f'Average reward per episode: {round(mean_rewards, 2)}', transform=ax[0].transAxes, size='large')
ax[0].set_title('Total reward per episode')

cumulative_rewards = [log['avg_reward'] for _, log in a2c.eval_logs.items()]
ax[1].plot(range(50), cumulative_rewards)
ax[1].set_title('Average reward per episode')
# Out:
# Text(0.5, 1.0, 'Average reward per episode')
