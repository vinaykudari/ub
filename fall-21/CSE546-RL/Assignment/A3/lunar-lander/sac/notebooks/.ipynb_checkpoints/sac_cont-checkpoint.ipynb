# %%
# add parent directory to path: enable import from parent dir
import sys
sys.path.append('../')

from agents.sac import SAC
import matplotlib.pyplot as plt
import gym

# %%
env = gym.make('LunarLanderContinuous-v2')

# %%
sac = SAC(
    env=env,
    name='lunar_lander',
    input_dim=env.observation_space.shape[0],
    log_freq=20,
)

# %%
sac.run(2000)
# Out:
# collecting experience...
# 0..20..40..
# ../agents/sac.py:257: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   rewards = T(rewards, dtype=torch.float, device=DEVICE)
# ../agents/sac.py:258: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dones = T(dones, dtype=torch.float, device=DEVICE)
# ../agents/sac.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   nxt_states = T(nxt_states, dtype=torch.float, device=DEVICE)
# ../agents/sac.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   states = T(states, dtype=torch.float, device=DEVICE)
# ../agents/sac.py:261: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   actions = T(actions, dtype=torch.float, device=DEVICE)
# Episode: 60, Reward: -231.25093018379187, Avg. Reward: -228.9903896762292, Policy Loss=2.31
# Episode: 80, Reward: -83.10285109804863, Avg. Reward: -182.41248401719696, Policy Loss=2.06
# Episode: 100, Reward: -0.08544839595377596, Avg. Reward: -67.34280338965253, Policy Loss=-11.17
# Episode: 120, Reward: 68.82026314851225, Avg. Reward: 19.15912912866913, Policy Loss=-20.18
# Episode: 140, Reward: 40.973614202976734, Avg. Reward: 44.397135530152774, Policy Loss=-21.56
# Episode: 160, Reward: 52.130089326289415, Avg. Reward: 39.658189813460744, Policy Loss=-22.0
# Episode: 180, Reward: 70.95644514476338, Avg. Reward: 32.63948561899363, Policy Loss=-18.45
# Episode: 200, Reward: 58.413375501619136, Avg. Reward: 34.814984107920516, Policy Loss=-20.7
# Episode: 220, Reward: 30.34998199519395, Avg. Reward: 37.76514172493907, Policy Loss=-21.82
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8395fc85217e> in <module>
# ----> 1 sac.run(2000)
#
# /home/vinaykudari/Desktop/temp/reinforcement-learning-algos/agents/sac.py in run(self, ep)
#     328                 state = nxt_state
#     329                 if self.memory.curr_size > self.mem_sz:
# --> 330                     v_loss, c_loss, p_loss = self.train(ep_no)
#     331
#     332                     if ep_no % 100:
#
# /home/vinaykudari/Desktop/temp/reinforcement-learning-algos/agents/sac.py in train(self, ep_no)
#     253     def train(self, ep_no):
#     254         states, actions, rewards, nxt_states, dones = \
# --> 255             self.memory.sample(self.mem_sz)
#     256
#     257         rewards = T(rewards, dtype=torch.float, device=DEVICE)
#
# /home/vinaykudari/Desktop/temp/reinforcement-learning-algos/helpers/replay_buffer.py in sample(self, batch_size)
#      39     def sample(self, batch_size):
#      40         idxes = np.random.randint(0, len(self._storage) - 1, batch_size)
# ---> 41         return self._encode_sample(idxes)
#
# /home/vinaykudari/Desktop/temp/reinforcement-learning-algos/helpers/replay_buffer.py in _encode_sample(self, idxes)
#      35             nxt_states.append(nxt_state)
#      36             dones.append(done)
# ---> 37         return t.stack(states), t.stack(actions), t.stack(rewards), t.stack(nxt_states), t.stack(dones)
#      38
#      39     def sample(self, batch_size):
#
# KeyboardInterrupt:

# %%
sac.evaluate()

# %% [markdown]
# ## Traning

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 8))

total_rewards = [log['reward'] for _, log in sac.logs.items()]
mean_rewards = sum(total_rewards)/len(total_rewards)
ax[0].plot(range(len(total_rewards)), total_rewards)
ax[0].text(0.5, 0.7, f'Average reward per episode: {round(mean_rewards, 2)}', transform=ax[0].transAxes, size='large')
ax[0].set_title('Total reward per episode')

cumulative_rewards = [log['avg_reward'] for _, log in sac.logs.items()]
ax[1].plot(range(len(total_rewards)), cumulative_rewards)
ax[1].set_title('Average reward per episode')
# Out:
# Text(0.5, 1.0, 'Average reward per episode')

# %% [markdown]
# ### Evaluation

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 8))

total_rewards = [log['reward'] for _, log in sac.eval_logs.items()]
mean_rewards = sum(total_rewards)/len(total_rewards)
ax[0].plot(range(len(total_rewards)), total_rewards)
ax[0].text(0.5, 0.7, f'Average reward per episode: {round(mean_rewards, 2)}', transform=ax[0].transAxes, size='large')
ax[0].set_title('Total reward per episode')

cumulative_rewards = [log['reward'] for _, log in sac.eval_logs.items()]
ax[1].plot(range(len(total_rewards)), cumulative_rewards)
ax[1].set_title('Average reward per episode')
# Out:
# Text(0.5, 1.0, 'Average reward per episode')
