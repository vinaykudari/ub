# %% [markdown]
# ### Factor Analysis
# This notebook illustrates Factor Analysis model and how to use sklearn.FactorAnalysis method to conduct factor analysis on a sample data set.

# %%
import numpy as np
import csv
from scipy.stats import norm
import pandas as pd
from sklearn.decomposition import FactorAnalysis
import matplotlib.pyplot as plt
import scipy.stats.mstats as ms
import mpld3
from mpld3 import plugins
# %matplotlib inline

# %%
# set the factor analysis model parameters
mu0 = 0
sigma0 = 1
W = np.array([8,1])
W = W[:,np.newaxis]
mu = np.array([0,0])
mu = mu[:,np.newaxis]
Psi = np.array([[1,0],[0,1]])

n = 1000
# sample z's from the distribution 
Z = norm(mu0, sigma0).rvs(n)
Z = Z[:,np.newaxis]
# generate x from z
X = []
for z in Z:
    mu1 = z*W + mu
    x = np.random.multivariate_normal(mu1.flatten(),Psi,1).flatten()
    X.append(x)
X = np.array(X)

# plot them side by side
fig, axs = plt.subplots(1, 3)
fig.set_size_inches([12,6])

P = np.zeros([4,n])
P[0] = Z.flatten()
P[2] = X[:,0]
P[3] = X[:,1]
x = np.linspace(-5,5,100)
axs[0].plot(x, 1/(sigma0 * np.sqrt(2 * np.pi)) * np.exp( - (x - mu0)**2 / (2 * sigma0**2) ), linewidth=2, color='r')
if n > 10:
    axs[0].hist(Z,alpha=0.3,bins=20,color='b',normed=True)

points = axs[0].scatter(P[0],P[1])
points = axs[1].scatter(P[2],P[3])
points = axs[2].scatter(P[0],P[2])
axs[0].set_ylim([-0.1,1])
if n > 1:
    axs[1].set_xlim([np.min(X),np.max(X)])
    axs[1].set_ylim([np.min(X),np.max(X)])
axs[0].legend(['true pdf','samples','empirical distribution'])
plugins.connect(fig, plugins.LinkedBrush(points))
mpld3.display(fig)
# Out:
# /Users/mgao8/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# <style>
#
# </style>
#
# <div id="fig_el377901122134374643437998805"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el377901122134374643437998805", {"width": 864.0, "height": 432.0, "axes": [{"bbox": [0.125, 0.125, 0.22794117647058826, 0.755], "xlim": [-5.5, 5.5], "ylim": [-0.1, 1.0], "xdomain": [-5.5, 5.5], "ydomain": [-0.1, 1.0], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 7, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el37790112257000168", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el37790112257173824", "color": "#FF0000", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data22", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el37790112257798496", "color": "#FF0000", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el37790112257567656", "dasharray": "none", "alpha": 0.3, "facecolor": "#0000FF", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el37790112257567152", "dasharray": "none", "alpha": 0.3, "facecolor": "#0000FF", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data04", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el37790112257614288", "dasharray": "none", "alpha": 0.3, "facecolor": "#0000FF", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data05", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el37790112257615184", "dasharray": "none", "alpha": 0.3, "facecolor": "#0000FF", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data06", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el37790112257616080", "dasharray": "none", "alpha": 0.3, "facecolor": "#0000FF", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data07", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el37790112257616976", "dasharray": "none", "alpha": 0.3, "facecolor": "#0000FF", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data08", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el37790112257617872", "dasharray": "none", "alpha": 0.3, "facecolor": "#0000FF", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data09", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el37790112257659792", "dasharray": "none", "alpha": 0.3, "facecolor": "#0000FF", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data10", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el37790112257660688", "dasharray": "none", "alpha": 0.3, "facecolor": "#0000FF", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data11", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el37790112257661584", "dasharray": "none", "alpha": 0.3, "facecolor": "#0000FF", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data12", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el37790112257662480", "dasharray": "none", "alpha": 0.3, "facecolor": "#0000FF", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data13", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el37 ...

# %%
fig, axs = plt.subplots(1, 3)
points = axs[0].scatter(P[0],P[1])
points = axs[1].scatter(P[0],P[1])
points = axs[2].scatter(P[2],P[3])
plugins.connect(fig, plugins.LinkedBrush(points))
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el377901122569809763580175676"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el377901122569809763580175676", {"width": 432.0, "height": 288.0, "axes": [{"bbox": [0.125, 0.125, 0.22794117647058826, 0.755], "xlim": [-3.1848234558304984, 3.7443798496418994], "ylim": [-0.015176600441501119, 0.015176600441501091], "xdomain": [-3.1848234558304984, 3.7443798496418994], "ydomain": [-0.015176600441501119, 0.015176600441501091], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 5, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 9, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el37790112213434776", "lines": [], "paths": [], "markers": [], "texts": [], "collections": [{"offsets": "data01", "xindex": 0, "yindex": 1, "paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "pathtransforms": [[6.0, 0.0, 0.0, 6.0, 0.0, 0.0]], "alphas": [null], "edgecolors": ["#1F77B4"], "facecolors": ["#1F77B4"], "edgewidths": [1.0], "offsetcoordinates": "data", "pathcoordinates": "display", "zorder": 1, "id": "el37790112260214400"}], "images": [], "sharex": [], "sharey": []}, {"bbox": [0.3985294117647059, 0.125, 0.2279411764705882, 0.755], "xlim": [-3.184823455830497, 3.7443798496419], "ylim": [-0.015176600441501119, 0.015176600441501091], "xdomain": [-3.184823455830497, 3.7443798496419], "ydomain": [-0.015176600441501119, 0.015176600441501091], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 5, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 9, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el37790112259868432", "lines": [], "paths": [], "markers": [], "texts": [], "collections": [{"offsets": "data01", "xindex": 0, "yindex": 1, "paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "pathtransforms": [[6.0, 0.0, 0.0, 6.0, 0.0, 0.0]], "alphas": [null], "edgecolors": ["#1F77B4"], "facecolors": ["#1F77B4"], "edgewidths": [1.0], "offsetcoordinates": "data", "pathcoordinates": "display", "zorder": 1, "id": "el37790112260243864"}], "images": [], "sharex":  ...

# %% [markdown]
# ### Analyzing data using Factor Analysis model

# %%
# Load data
X = np.zeros((387,11))
names = []
with open('data/04cars.dat','r') as f:
    reader = csv.reader(f)
    l1 = next(reader)
    lind = 0
    for row in reader:
        names.append(row[0])
        X[lind,:] = row[8:]
        lind = lind + 1

# %%
# Setup the factor analysis model
fa = FactorAnalysis(n_components=2)
# fit the data
zX = ms.zscore(X)
f = fa.fit(zX)
W = ms.zscore(np.transpose(f.components_))
Psi = f.noise_variance_

# %%
# We first visualize and interpret the W matrix
fig = plt.figure(figsize=[10,8])
for i in range(W.shape[0]):
    plt.plot([0,W[i,0]],[0,W[i,1]])
    plt.text(W[i,0],W[i,1],l[i])
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el377901122134058246108891299"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el377901122134058246108891299", {"width": 720.0, "height": 576.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-1.9497683072944194, 1.3841985061966766], "ylim": [-1.0491020741791064, 1.9320179259060382], "xdomain": [-1.9497683072944194, 1.3841985061966766], "ydomain": [-1.0491020741791064, 1.9320179259060382], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 8, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el37790112211861912", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el37790112254961872", "color": "#1F77B4", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el37790112254992568", "color": "#FF7F0E", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el37790112254994248", "color": "#2CA02C", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data04", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el37790112254995872", "color": "#D62728", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data05", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el37790112255030384", "color": "#9467BD", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data06", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el37790112255032064", "color": "#8C564B", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data07", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el37790112255066576", "color": "#E377C2", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data08", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el37790112255068256", "color": "#7F7F7F", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data09", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el37790112255069936", "color": "#BCBD22", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data10", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el37790112255104448", "color": "#17BECF", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data11", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el37790112254837424", "color": "#1F77B4", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}], "paths": [], "markers": [], "texts": [{"text": "Retail Price", "position": [1.2326545601288996, 0.6041525721588208], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el37790112254962320"}, {"text": "Dealer Price", "position": [1.2325323663443548, 0.6150689875171608], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el37790112254992960"}, {"text": "Engine Size", "position": [0.4191939116330512, -0.7280837882051835], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el37790112254994584"}, {"text": "Cylinders", "position": [0.5324055770329821, -0.5169986259248707], "coordinates": "data", "h_anchor" ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#          mpld3.draw_figure("fig_el377901122134058246108891299", {"width": 720.0, "height": 576.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-1.9497683072944194, 1.3841985061966766], "ylim": [-1.0491020741791064, 1.9320179259060382

# %%
# Find latent scores for each data point using the latent factors
Z = f.fit_transform(zX)
fig = plt.figure(figsize=[12,10])
#for i in range(W.shape[0]):
#    plt.plot([0,W[i,0]],[0,W[i,1]])

scatter = plt.scatter(Z[:,0],Z[:,1])
#for i in range(Z.shape[0]):
    #if abs(Z[i,0]) > 1.5 or abs(Z[i,1]) > 1.5:
    #plt.text(Z[i,0],Z[i,1],names[i],fontsize=8)
    
labels1 = ['%s'%(names[i]) for i in range(Z.shape[0])]
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels1)
mpld3.plugins.connect(fig, tooltip)
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el377901122203893282960847847"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el377901122203893282960847847", {"width": 864.0, "height": 720.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-1.6280183099407852, 8.478085543930352], "ylim": [-3.5110977648289317, 5.500971308330147], "xdomain": [-1.6280183099407852, 8.478085543930352], "ydomain": [-3.5110977648289317, 5.500971308330147], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 7, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 6, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el37790112220389272", "lines": [], "paths": [], "markers": [], "texts": [], "collections": [{"offsets": "data01", "xindex": 0, "yindex": 1, "paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "pathtransforms": [[6.0, 0.0, 0.0, 6.0, 0.0, 0.0]], "alphas": [null], "edgecolors": ["#1F77B4"], "facecolors": ["#1F77B4"], "edgewidths": [1.0], "offsetcoordinates": "data", "pathcoordinates": "display", "zorder": 1, "id": "el37790112252099832"}], "images": [], "sharex": [], "sharey": []}], "data": {"data01": [[-1.0983268266993975, 1.2721586336121071], [-1.05272267831906, 1.4187122232383875], [-0.945264217174903, 0.7024636785013182], [-0.9350541064573328, 0.7356851047181396], [-0.8542719169626465, 0.762985500812156], [-0.9938687652501866, 0.9332129963489216], [-0.9247473879260039, 0.961137983580595], [-1.0137606869084381, 0.8920542526410308], [-0.9912934617615733, 1.0054572467748981], [-0.9024238477859863, 0.9681037998463399], [-0.8961499883111527, 0.939027847065136], [-1.024253905953339, 1.184055738067762], [-0.9794775324471516, 1.3523623283895285], [-0.8932285407072437, 1.1894483431972098], [-1.1517426319868813, 1.321435847935579], [-1.0906055125794567, 1.3462920346818146], [-1.0854037128647704, 1.330586807014257], [-0.9903853993352573, 0.774491736289218], [-0.9115623464088533, 0.8266773962674714], [-0.9114472641116586, 0.8021199665301757], [-0.872269183049575, 0.06640664800694589], [-1.1641696662082912, 1.219975505035906], [-1.1187003475202162, 1.1949806586649006], [-1.0603002730042748, 0.7609214311801128], [-0.9961232333150778, 0.7944382502476184], [-0.9428684759688004, 0.825332949037736], [-0.8394121922580504, 1.5640052304669783], [-1.036007359909282, 1.0210392544004552], [-0.9422020154128997, 1.0534719085383444], [-0.9032265907910615, 0.6252915051995733], [-1.1304825179526135, 0.6190395205064979], [-0.9615118652134426, 0.7312539830484516], [-0.8835561567304284, 0.7830206191633997], [-0.9331507739978234, 0.6775126564384083], [-0.8564664050781383, 0.7284375883601585], [-1.0291827099603865, 1.6273427288180002], [-1.0158273800971496, 0.7268596941624745], [-0.9306508855937682, 0.7844031776847958], [-1.0491979223886492, 0.6876554641852928], [-0.8749165265766712, 0.7326115357272664], [-0.9784986121657786, 1.1688467259471975], [-0.9380615366771227, 1.1840735150108614], [-0.9247146157442148, 1.192860321753191], [-1.1473111342941906, 1.830895421891799], [-1.105520804763151, 1.7386121768857041], [-1.1200420982058543, 1.841 ...
