# %% [markdown]
# ### Factor Analysis
# This notebook illustrates Factor Analysis model and how to use sklearn.FactorAnalysis method to conduct factor analysis on a sample data set.

# %%
import numpy as np
import csv
from scipy.stats import norm
#import pandas as pd
from sklearn.decomposition import FactorAnalysis
import matplotlib.pyplot as plt
import scipy.stats.mstats as ms
import mpld3
from mpld3 import plugins
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-274dc7476256> in <module>()
#       3 from scipy.stats import norm
#       4 #import pandas as pd
# ----> 5 from sklearn.decomposition import FactorAnalysis
#       6 import matplotlib.pyplot as plt
#       7 import scipy.stats.mstats as ms
#
# ImportError: No module named sklearn.decomposition

# %%
# set the factor analysis model parameters
mu0 = 0
sigma0 = 1
W = np.array([8,1])
W = W[:,np.newaxis]
mu = np.array([0,0])
mu = mu[:,np.newaxis]
Psi = np.array([[1,0],[0,1]])

n = 1000
# sample z's from the distribution 
Z = norm(mu0, sigma0).rvs(n)
Z = Z[:,np.newaxis]
# generate x from z
X = []
for z in Z:
    mu1 = z*W + mu
    x = np.random.multivariate_normal(mu1.flatten(),Psi,1).flatten()
    X.append(x)
X = np.array(X)

# plot them side by side
fig, axs = plt.subplots(1, 3)
fig.set_size_inches([12,6])

P = np.zeros([4,n])
P[0] = Z.flatten()
P[2] = X[:,0]
P[3] = X[:,1]
x = np.linspace(-5,5,100)
axs[0].plot(x, 1/(sigma0 * np.sqrt(2 * np.pi)) * np.exp( - (x - mu0)**2 / (2 * sigma0**2) ), linewidth=2, color='r')
if n > 10:
    axs[0].hist(Z,alpha=0.3,bins=20,color='b',normed=True)

points = axs[0].scatter(P[0],P[1])
points = axs[1].scatter(P[2],P[3])
points = axs[2].scatter(P[0],P[2])
axs[0].set_ylim([-0.1,1])
if n > 1:
    axs[1].set_xlim([np.min(X),np.max(X)])
    axs[1].set_ylim([np.min(X),np.max(X)])
axs[0].legend(['true pdf','samples','empirical distribution'])
plugins.connect(fig, plugins.LinkedBrush(points))
mpld3.display(fig)
# Out:
# /Users/chandola/anaconda/lib/python2.7/site-packages/mpld3/mplexporter/exporter.py:171: UserWarning: Legend element <matplotlib.collections.PathCollection object at 0x114ac0850> not impemented
#   warnings.warn("Legend element %s not impemented" % child)
# <style>
#
# </style>
#
# <div id="fig_el59674842303120453348194"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el59674842303120453348194", {"axes": [{"xlim": [-6.0, 6.0], "yscale": "linear", "axesbg": "none", "texts": [{"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [-0.54838709677419339, -0.16129032258064516], "rotation": -0.0, "id": "el59674641787152"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "true pdf", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [0.29502268145161314, 0.9408602150537636], "rotation": -0.0, "id": "el59674695193040"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "samples", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [0.29502268145161314, 0.88799283154121877], "rotation": -0.0, "id": "el59674690579152"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "empirical distribution", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [0.29502268145161314, 0.83512544802867394], "rotation": -0.0, "id": "el59674641787408"}], "zoomable": true, "images": [], "xdomain": [-6.0, 6.0], "ylim": [-0.10000000000000001, 1.0], "paths": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.3, "xindex": 0, "data": "data02", "id": "el59674784390032"}, {"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.3, "xindex": 0, "data": "data03", "id": "el59674730056400"}, {"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.3, "xindex": 0, "data": "data04", "id": "el59674730054672"}, {"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.3, "xindex": 0, "data": "data05", "id": "el59674691071824"}, {"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.3, "xindex": 0, "data": "data06", "id": "el59674637957712"}, {"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.3, "xindex": 0, "data": "data07", "id": "el59674637955408"}, {"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.3, "xindex": 0, "data": "data08", "id": "el59674637731152"}, {"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.3, "xindex": 0, "data": "data09", "id": "el59674637730832"}, {"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.3, "xindex": 0, "data": "data10", "id": "el59674742876368"}, {"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.3, "xindex": 0, "data": "data11", "id": "el59674742874512"}, {"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.3, "xindex": 0, "data": "data12",  ...

# %%
fig, axs = plt.subplots(1, 3)
points = axs[0].scatter(P[0],P[1])
points = axs[1].scatter(P[0],P[1])
points = axs[2].scatter(P[2],P[3])
plugins.connect(fig, plugins.LinkedBrush(points))
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el596748097070242800472392"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el596748097070242800472392", {"axes": [{"xlim": [-5.0, 4.0], "yscale": "linear", "axesbg": "none", "texts": [], "zoomable": true, "images": [], "xdomain": [-5.0, 4.0], "ylim": [-0.01, 0.01], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "bottom", "nticks": 10, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [], "markers": [], "id": "el59674755398608", "ydomain": [-0.01, 0.01], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [1.0], "offsets": "data01", "yindex": 1, "id": "el59674789025104", "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#0000FF"]}], "xscale": "linear", "bbox": [0.125, 0.125, 0.22794117647058826, 0.77500000000000002]}, {"xlim": [-5.0, 4.0], "yscale": "linear", "axesbg": "none", "texts": [], "zoomable": true, "images": [], "xdomain": [-5.0, 4.0], "ylim": [-0.01, 0.01], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "bottom", "nticks": 10, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [], "markers": [], "id": "el59674781996944", "ydomain": [-0.01, 0.01], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [1.0], "offsets": "data01", "yindex": 1, "id": "el59674787521552", "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#0000FF"]}], "xscale": "linear", "bbox": [0.39852941176470591, 0.125, 0.2279411764705882, 0.77500000000000002]}, {"xlim": [-40.0, 40.0], "yscale": "linear", "axesbg": "none", "texts": [], "zoomable": true, "images": [], "xdomain": [-40.0, 40.0], "ylim": [-6.0, 6.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat ...

# %% [markdown]
# ### Analyzing data using Factor Analysis model

# %%
# Load data
X = np.zeros((387,11))
names = []
with open('../data/04cars.dat','r') as f:
    reader = csv.reader(f)
    l1 = reader.next()
    lind = 0
    for row in reader:
        names.append(row[0])
        X[lind,:] = row[8:]
        lind = lind + 1
# variable names
l = l1[8:]

# %%
# Setup the factor analysis model
fa = FactorAnalysis(n_components=2)
# fit the data
zX = ms.zscore(X)
f = fa.fit(zX)
W = ms.zscore(np.transpose(f.components_))
Psi = f.noise_variance_

# %%
# We first visualize and interpret the W matrix
fig = plt.figure(figsize=[10,8])
for i in range(W.shape[0]):
    plt.plot([0,W[i,0]],[0,W[i,1]])
    plt.text(W[i,0],W[i,1],l[i])
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el596747957230246181112586"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el596747957230246181112586", {"axes": [{"xlim": [-2.0, 1.5], "yscale": "linear", "axesbg": "none", "texts": [{"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Retail Price", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [1.2326545601289594, 0.60415257216108587], "rotation": -0.0, "id": "el59674782733136"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Dealer Price", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [1.2325323663444132, 0.61506898751941907], "rotation": -0.0, "id": "el59674782785296"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Engine Size", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.41919391163302899, -0.72808378820743569], "rotation": -0.0, "id": "el59674782787984"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Cylinders", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.53240557703297231, -0.51699862592744383], "rotation": -0.0, "id": "el59674782839888"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Horsepower", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.89934210169999618, -0.045541242487983406], "rotation": -0.0, "id": "el59674782887696"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "City MPG", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [-1.798224361226584, 1.7768506973912006], "rotation": -0.0, "id": "el59674782890384"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Highway MPG", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [-1.7657356905720054, 1.7965124712825356], "rotation": -0.0, "id": "el59674782938192"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Weight", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.16961128995487476, -0.88738392391499599], "rotation": -0.0, "id": "el59674782981904"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Wheel Base", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [-0.38266449520673335, -0.89402400252716296], "rotation": -0.0, "id": "el59674782984592"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Length", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [-0.3731798570018075, -0.80695652565839648], "rotation": -0.0, "id": "el59674783036496"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Width", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [-0.16593540278711327, -0.91359661963082239], "rotation": -0.0, "id": "el59674783076112"}], "zoomable": true, "images": [], "xdomain": [-2.0, 1.5], "ylim": [-1.0, 2.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "bottom", "nticks": 8, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data01", "id": "el59674782732432"}, {"color": "#007F00", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data02", "id": "el59674782784656"}, {"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data03", "id": "el59674782787344"}, {"color": "#00BFBF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xi ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el596747957230246181112586", {"axes": [{"xlim": [-2.0, 1.5], "yscale": "linear", "axesbg": "none", "texts": [{"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Retail Price", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [1.2326545601289594, 0.60415257216108587], "rotation": -0.0, "id": "el59674782733136"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Dealer Price", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [1.2325323663444132, 0.61506898751941907], "rotation": -0.0, "id": "el59674782785296"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#

# %%
# Find latent scores for each data point using the latent factors
Z = f.fit_transform(zX)
fig = plt.figure(figsize=[12,10])
#for i in range(W.shape[0]):
#    plt.plot([0,W[i,0]],[0,W[i,1]])

scatter = plt.scatter(Z[:,0],Z[:,1])
#for i in range(Z.shape[0]):
    #if abs(Z[i,0]) > 1.5 or abs(Z[i,1]) > 1.5:
    #plt.text(Z[i,0],Z[i,1],names[i],fontsize=8)
    
labels1 = ['%s'%(names[i]) for i in range(Z.shape[0])]
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels1)
mpld3.plugins.connect(fig, tooltip)
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el59674782173328594016267"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el59674782173328594016267", {"axes": [{"xlim": [-2.0, 10.0], "yscale": "linear", "axesbg": "none", "texts": [], "zoomable": true, "images": [], "xdomain": [-2.0, 10.0], "ylim": [-4.0, 6.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [], "markers": [], "id": "el59674795722832", "ydomain": [-4.0, 6.0], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [1.0], "offsets": "data01", "yindex": 1, "id": "el59674783576208", "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#0000FF"]}], "xscale": "linear", "bbox": [0.125, 0.125, 0.77500000000000002, 0.77500000000000002]}], "height": 800.0, "width": 960.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"voffset": 10, "labels": ["Chevrolet Aveo 4dr", "Chevrolet Aveo LS 4dr hatch", "Chevrolet Cavalier 2dr", "Chevrolet Cavalier 4dr", "Chevrolet Cavalier LS 2dr", "Dodge Neon SE 4dr", "Dodge Neon SXT 4dr", "Ford Focus ZX3 2dr hatch", "Ford Focus LX 4dr", "Ford Focus SE 4dr", "Ford Focus ZX5 5dr", "Honda Civic DX 2dr", "Honda Civic HX 2dr", "Honda Civic LX 4dr", "Hyundai Accent 2dr hatch", "Hyundai Accent GL 4dr", "Hyundai Accent GT 2dr hatch", "Hyundai Elantra GLS 4dr", "Hyundai Elantra GT 4dr", "Hyundai Elantra GT 4dr hatch", "Kia Optima LX 4dr", "Kia Rio 4dr manual", "Kia Rio 4dr auto", "Kia Spectra 4dr", "Kia Spectra GS 4dr hatch", "Kia Spectra GSX 4dr hatch", "Mini Cooper", "Nissan Sentra 1.8 4dr", "Nissan Sentra 1.8 S 4dr", "Pontiac Sunfire 1SA 2dr", "Saturn Ion1 4dr", "Saturn lon2 4dr", "Saturn lon3 4dr", "Saturn lon2 quad coupe 2dr", "Saturn lon3 quad coupe 2dr", "Scion xA 4dr hatch", "Suzuki Aeno S 4dr", "Suzuki Aerio LX 4dr", "Suzuki Forenza S 4dr", "Suzuki Forenza EX 4dr", "Toyota Corolla CE 4dr", "Toyota Corolla S 4dr", "Toyota Corolla LE 4dr", "Toyota Echo 2dr manual", "Toyota Echo 2dr auto", "Toyota Echo 4dr", "Buick Century Custom 4dr", "Chevrolet Impala 4dr", "Chevrolet Malibu 4dr", "Chevrolet Malibu LS 4dr", "Chevrolet Monte Carlo LS 2dr", "Chrysler PT Cruiser 4dr", "Chrysler PT Cruiser Limited 4dr", "Chrysler Sebring 4dr", "Chrysler Sebring Touring 4dr", "Dodge Intrepid SE 4dr", "Dodge Stratus SXT 4dr", "Dodge Stratus SE 4dr", "Ford Focus SVT 2dr", "Ford Taurus LX 4dr", "Ford Taurus SES Duratec 4dr", "Honda Accord LX 2dr", "Honda Accord EX 2dr", "Honda Civic EX 4dr", "Honda Civic Si 2dr hatch", "Honda Civic Hybrid 4dr manual", "Honda Insight 2dr (gas/electric)", "Hyundai Sonata GLS 4dr", "Hyundai Sonata LX 4dr", "Kia Optima LX V6 4dr", "Mazda6 i 4dr", "Mercury Sable GS 4dr", "Mini Cooper S", "Nissan Altima S 4dr", "Nissan Sentra SE-R 4dr", "Oldsmobile Alero GX 2dr", "Pontiac Grand Am  ...

# %%
322474819
