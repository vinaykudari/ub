# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.text as txt
import matplotlib.lines as lines
from matplotlib.colors import ListedColormap
import time
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from sklearn.neural_network import MLPClassifier
from IPython import display
import pylab as pl
# %matplotlib inline
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

# %% [markdown]
# ### Investigating the role of regularization on the learning boundary learnt by a neural network

# %%
# generate uniformly sampled data
delta = 0.1
X = np.random.uniform(size=[1000,2])
# split in two classes using a linear boundary
y = np.zeros([X.shape[0],1])
for i in range(X.shape[0]):
    if 2.5*X[i,0] + X[i,1] > 1.75 + delta:
        y[i] = 1
    elif 2.5*X[i,0] + X[i,1] < 1.75 - delta:
        y[i] = 0
    else:
        y[i] = -1
# remove examples with negative labels
inds = np.where(y != -1)[0]
X = X[inds,:]
y = y[inds]
# randomly flip some of the indices
fr = np.random.permutation(len(y))[0:200]
for i in fr:
    y[i] = 1- y[i]
# plot data
plt.scatter(X[:,0],X[:,1],c=y[:,0],cmap=cm_bright)

# %%
# sample training data
tr = np.random.permutation(len(y))[0:100]
# ensure that all the mislabeled points are in the training data
#tr = list(set(tr).union(set(fr)))
trainX = X[tr,:]
trainy = y[tr].ravel()
plt.scatter(trainX[:,0],trainX[:,1],c=trainy,cmap=cm_bright)

# %%
# learn a neural network with no regularization
clf = MLPClassifier(activation='logistic',solver='lbfgs', momentum=0,alpha=1e-1000,hidden_layer_sizes=(100,100), random_state=1)
clf.fit(trainX, trainy) 
sweights = 0
for i in range(clf.n_layers_-1):
    sweights += np.sum(np.abs(clf.coefs_[i]))
trainMistakes = len(np.where(clf.predict(trainX) != trainy)[0])
aM = set(np.where(clf.predict(X) != y.ravel())[0]).difference(set(fr))
allMistakes = len(aM)

# plot the decision surface
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(1,2,1)

print(trainX.shape)
print(trainy.shape)
print(clf)

plotBoundary(trainX,trainy,clf,ax)

ax.set_title('Training Data. Mistakes = %d of %d'%(trainMistakes,len(trainy)))
ax = fig.add_subplot(1,2,2)
plotBoundary(X,y,clf,ax)
ax.set_title('All Data. Mistakes = %d of %d'%(allMistakes,len(y)))
print('Sum of weights = %.2f'%sweights)
# Out:
# (100, 2)
# (100,)
# MLPClassifier(activation='logistic', alpha=0.0, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 100), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-3854f346c6ec> in <module>()
#      17 print(clf)
#      18
# ---> 19 plotBoundary(trainX,trainy,clf,ax)
#      20
#      21 ax.set_title('Training Data. Mistakes = %d of %d'%(trainMistakes,len(trainy)))
#
# <ipython-input-14-2c171bffd7e4> in plotBoundary(X, y, clf, ax)
#      11     cm_bright = ListedColormap(['#FF0000', '#0000FF'])
#      12     ax.pcolormesh(X1_, X2_, ypred, cmap=cm_bright,alpha=.2)
# ---> 13     sp = ax.scatter(X[:, 0], X[:, 1], c=y[:,0], cmap=cm_bright)
#      14
#      15     ax.set_xlim(X1_.min(), X1_.max())
#
# IndexError: too many indices for array

# %%
# learn a neural network with regularization
clf = MLPClassifier(activation='logistic',solver='lbfgs', momentum=0,alpha=0.1,hidden_layer_sizes=(100,100), random_state=1)
clf.fit(trainX, trainy) 
sweights = 0
for i in range(clf.n_layers_-1):
    sweights += np.sum(np.abs(clf.coefs_[i]))

trainMistakes = len(np.where(clf.predict(trainX) != trainy)[0])
# do not count the flipped instances as mistakes
aM = set(np.where(clf.predict(X) != y.ravel())[0]).difference(set(fr))
allMistakes = len(aM)

# plot the decision surface
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(1,2,1)
plotBoundary(trainX,trainy,clf,ax)
ax.set_title('Training Data. Mistakes = %d of %d'%(trainMistakes,len(trainy)))
ax = fig.add_subplot(1,2,2)
plotBoundary(X,y,clf,ax)
ax.set_title('All Data. Mistakes = %d of %d'%(allMistakes,len(y)))
print('Sum of weights = %.2f'%sweights)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     131     try:
# --> 132         rgba = _colors_full_map.cache[c, alpha]
#     133     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3985                 # must be acceptable as PathCollection facecolors
# -> 3986                 colors = mcolors.to_rgba_array(c)
#    3987             except ValueError:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     232     for i, cc in enumerate(c):
# --> 233         result[i] = to_rgba(cc, alpha)
#     234     return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     133     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 134         rgba = _to_rgba_no_colorcycle(c, alpha)
#     135         try:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     188     if len(c) not in [3, 4]:
# --> 189         raise ValueError("RGBA sequence should have length 3 or 4")
#     190     if len(c) == 3 and alpha is None:
#
# ValueError: RGBA sequence should have length 3 or 4
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d1cd1c620e96> in <module>()
#      17 ax.set_title('Training Data. Mistakes = %d of %d'%(trainMistakes,len(trainy)))
#      18 ax = fig.add_subplot(1,2,2)
# ---> 19 plotBoundary(X,y,clf,ax)
#      20 ax.set_title('All Data. Mistakes = %d of %d'%(allMistakes,len(y)))
#      21 print('Sum of weights = %.2f'%sweights)
#
# <ipython-input-4-bf08a4505ed7> in plotBoundary(X, y, clf, ax)
#      11     cm_bright = ListedColormap(['#FF0000', '#0000FF'])
#      12     ax.pcolormesh(X1_, X2_, ypred, cmap=cm_bright,alpha=.2)
# ---> 13     sp = ax.scatter(X[:, 0], X[:, 1], c=y, cmap=cm_bright)
#      14
#      15     ax.set_xlim(X1_.min(), X1_.max())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3989                 msg = ("c of shape {0} not acceptable as a color sequence "
#    3990                        "for x with size {1}, y with size {2}")
# -> 3991                 raise ValueError(msg.format(c.shape, x.size, y.size))
#    3992         else:
#    3993             colors = None  # use cmap, norm after collection is created
#
# ValueError: c of shape (923, 1) not acceptable as a color sequence for x with size 923, y with size 923

# %%
def plotBoundary(X,y,clf,ax):
    h = .01  # step size in the mesh

    X1_min, X1_max = X[:, 0].min() - .1, X[:, 0].max() + .1
    X2_min, X2_max = X[:, 1].min() - .1, X[:, 1].max() + .1
    X1_, X2_ = np.meshgrid(np.arange(X1_min, X1_max, h),np.arange(X2_min, X2_max, h))
    Xpred = np.c_[X1_.ravel(), X2_.ravel()]
    ypred = clf.predict(Xpred)
    ypred = ypred.reshape(X1_.shape)
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])
    ax.pcolormesh(X1_, X2_, ypred, cmap=cm_bright,alpha=.2)
    sp = ax.scatter(X[:, 0], X[:, 1], c=y[:,0], cmap=cm_bright)
    
    ax.set_xlim(X1_.min(), X1_.max())
    ax.set_ylim(X2_.min(), X2_.max())
    ax.set_xticks(())
    ax.set_yticks(())
