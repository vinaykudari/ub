# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
training_data = [
    ((1, 1), 1),
    ((7, -2), 1),
    ((3, -2), 1),
    ((1, 3), -1),
    ((3, 4), -1),
    ((3, 5), -1),
    ((5, 5), -1),
    ((7, 6), -1),
]

# %%
X = np.array([i[0][0] for i in training_data])
y = np.array([i[0][1] for i in training_data])
c = ['b' if i[1] == 1 else 'r' for i in training_data]

# %%
plt.scatter(X, y, color=c)
plt.plot(yy, xx)

# %%
from sklearn import svm

clf = svm.SVC(kernel='linear')
clf.fit(X.reshape(-1, 1), y)
# Out:
# SVC(kernel='linear')

# %%
xx = []
yy = []

for i, _ in traning_data:
    z = clf.predict(np.array(i).reshape(-1, 1))
    xx.append(z[0])
    yy.append(z[1])
