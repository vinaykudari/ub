# %% [markdown]
# ### Part - A

# %% [markdown]
# #### Differentiate Data Parallelism and Task Parallelism?
#
# | Data Parallelism                                                                         | Task Parallelism                                                                                    |
# |------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------|
# | Data Parallelism is dividing data among different nodes and processing them in parallel. | Task Parallelism is processing different tasks on same dataset on different cores                   |
# | Amount of speedup is dependent on input size                                             | Amount of speedup is dependent on number of independent tasks                                       |
# | Synchronous in nature                                                                    | Asynchronous in nature                                                                              |
# | Speedup is more as there is only one execution thread operating on all sets of data      | Speedup is less as each processor executes a different process on the same or different set of data |
# |                                                                                          |                                                                                                     |

# %% [markdown]
# #### SIMD Data parallelism with an example?
#
# Single Instruction multiple data is one type of data parallelism, where same instruction is executed across different elements of dataset. This kind of data parallelism is generally used in most data analytical frameworks, list of data elements is considered as a vector and mathematical operations such as multiplication, addition are performed in parallel between two vector elements.
#
#
#
# ![Unknown.jpeg](attachment:54b3b607-142a-45af-9e9d-5aa78e0fbeac.jpeg)
#
# In the above example figure (b) represents SIMD operation, we can observe that vector C is obtained by adding vector A and vector B here the operation is performed simultaneously for each of the scalars in contrast to scalar operation where each operation is performed serially.

# %% [markdown]
# #### What is MapReduce? Illustrate working of MapReduce with an example?
#
# MapReduce is a programming framework that allows us to perform distributed and parallel processing on large data sets in a distributed environment. It has two distinctive tasks, Map and Reduce. Map task takes <key, value> pairs as input from the disk and divide these pairs into smaller blocks as intermediate output, each block is then assigned to a mapper for processing After all the mappers complete processing, the framework shuffles and sorts the results before passing them on to the reducers. All the map outputs values that have the same key are mapped to the same reducer and the associated reducer aggregates the values for that key.
#
# There are two intermediate steps between Map and Reduce.
#
# Combine is an optional process. It reduces the data on each mapper to a simplified form before passing it downstream.
#
# Partition is the process that translates the <key, value> pairs resulting from mappers to another set of <key, value> pairs to feed into the respective reducers.
#
# ##### Example: Word Count
#
# Our task is to identify unique words and number of occurrences of those unique words.
#
# ![1*mHQOWVAZKjU82sKZkxaKhQ.png](attachment:1fdfdf8f-1861-4524-bab3-9493fad5da14.png)
#
#
# First, we divide the input into three splits as shown in the figure. This will distribute the work among all the map nodes.
#
# Next, in mapping phase we tokenize the words in each of the mappers and give a hardcoded value of 1 to each of the tokens
#
# The <key, value> pairs undergo shuffling process where the tuples with same key are passed to the corresponding reducer
#
# Now, each reducer counts the values in its list and outputs the final result as <key, count>

# %% [markdown]
# #### What are HDFS and YARN? What is the major advancement in Hadoop 2.0 from Hadoop 1.0? What is the impact of this advancement?
#
# Hadoop Distributed File System (HDFS) is a Java-based distributed file system that that provides scalable and reliable data storage, and it was designed to span large clusters of commodity servers. HDFS is a scalable, fault-tolerant, distributed storage system that works closely with a wide variety of concurrent data access applications, coordinated by YARN.
#
# Yet Another Resource Negotiator (YARN) is responsible for allocating system resources to the various applications running in a Hadoop cluster and scheduling tasks to be executed on different cluster nodes. YARN can dynamically allocate resources to applications as needed, a capability designed to improve resource utilization and application performance compared with MapReduce's more static allocation approach.
#
# In Hadoop 1.0 both application management and resource management were done by the MapReduce but with Hadoop 2, resource management has been replaced with YARN. In Hadoop 2, MapReduce is managing application management and YARN is managing the resources
#
# ![Hadoop-1-vs-Hadoop-2-Architecture.png](attachment:3df9c1ac-c183-42d4-9427-3adb988ce623.png)
#
# In Hadoop 1.0 there was a fixed number of map and reduce slots and it was a issue with large size cluster. YARN came to solve this problem in Hadoop 2.0, it gives us the scalability and proper resource utilization and dynamic allocation, and there is no longer fixed amount of map and reduce slots.
#
# Hadoop 2.0 YARN has the following advantages
#
# - High Scalability
# - High Availability
# - Supports Multiple Programming Models
# - Supports Multi-Tenancy
# - Supports Multiple Namespaces
# - Improved Cluster Utilization
# - Supports Horizontal Scalability

# %% [markdown]
# #### Explain that HDFS is fault tolerant?
#
# Fault tolerance refers to the ability of the system to work or run even under adverse conditions like component failures. In traditional systems such as relational databases, all read and write operations are done on one machine. If any adverse conditions such as RAM crash, computer failure, hard disk failure, power failure, etc. occur, the user must wait until the problem is manually solved. Therefore, during a computer crash or malfunction, users will be unable to access their data until the error in the computer is recovered. Following methods are used to ensure fault tolerance in HDFS
#
# Replication Mechanism
#
# In Hadoop Failure of one node doesn’t affect accessing (read-write operation) of data in datanode. Multiple copies of same block will be available in other datanode, So failure of one node will not impact the processing and we can make use of block from other datanode when one of the datanode (slaves) fails. The number of replicas created depends on the replication factor with a default value of 3. A high replication factor means more protection against hardware failures, and better chances for data locality. However, it also means increased storage space is required to use.
#
# Erasure Coding
#
# Erasure coding (EC) is a method of data protection in which data is broken into fragments, expanded and encoded with redundant data pieces and stored across a set of different locations or storage media. Hence

# %% [markdown]
# #### Discuss the advantages of cloud computing. Why was it crucial to launch the Big Data Era?
#
# Advantages of cloud computing
#
# - Cost Saving: The cost of setting up own server farms can be quite expensive. Currently cloud services offer pay per use business model which can help cut costs and invest this captial in R&D
# - Time Saving: Most cloud services provide VM's with preinstalled software, which can be quite time saving. Developers can focus on solving application specific challenges instead of building infrastructure
# - Manageability: Cloud Computing eliminates the need for IT infrastructure updates and maintenance since the service provider ensures timely, guaranteed, and seamless delivery of our services and also takes care of all the maintenance and management of our IT services according to the service-level agreement (SLA).
# - Reliability: Cloud hosting comes with the biggest advantage of reliability. One doesn’t have to worry about changes due to instant updates.
# - Collaboration: Cloud computing platforms help employees located in different locations to conveniently and securely collaborate with each other.
#
# In big data analytics we deal with large volumes of data and to process this data we will need high compute power, it can quite expensive to setup own and set up infrastructure, as our demand for compute power can be changing with time. Many companies might not have flourished without cloud computing.
#
# - The cloud can help process and analyze the big data faster and lead to insights that can improve products and business without a huge investment
# - The cloud’s scalable environment makes it possible to deploy data-intensive applications that deal with petabytes of data with few clicks
# - The cloud simplifies connectivity and collaboration within an organization and helps data sharing of relevant analytics and streamlines

# %% [markdown]
# #### Describe different cloud service models?
#
# IaaS: Infrastructure-as-a-Service, or "IaaS," is a type of cloud computing that provides clients with basic compute, network, and storage capabilities on-demand, through the internet, and on a pay-as-you-go basis. IaaS allows end users to scale and reduce resources as needed, avoiding the need for large, upfront capital investments or needless "owned" equipment, particularly for "spiky" workloads. Unlike PaaS and SaaS (and even newer computing paradigms like containers and serverless), IaaS gives you the most control over your cloud resources.
#
# PaaS: PaaS is a complete cloud development and deployment environment with resources that enable you to produce everything from simple cloud-based apps to sophisticated, cloud-enabled business systems. PaaS, like IaaS, contains infrastructure—servers, storage, and networking—as well as middleware, development tools, BI services, database management systems, and other services. PaaS is intended to support the entire web application lifecycle, including development, testing, deployment, management, and update.
#
# SaaS: Software as a service (SaaS) is a method of delivering software as a service through the Internet. Instead of installing and maintaining software, you simply use the Internet to access it, eliminating the need for complicated software and device maintenance. Web-based software, on-demand software, and hosted software are all terms used to describe SaaS applications. SaaS apps, whatever their name, are hosted on the servers of a SaaS provider. The service provider is in charge of the application's security, availability, and performance.
#
# ![what-is-paas.png](attachment:781ba021-1868-4c60-8f02-0d618d3fbd8c.png)
